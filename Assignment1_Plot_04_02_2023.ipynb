# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv('heart_disease_uci.csv')

df['trestbps'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
x=df["age"]
y=df["trestbps"]
plt.xlabel("Age")
plt.ylabel("Trestbps")
plt.title("Heart Rate Disease Plot")
plt.scatter(x,y)

# %%
df.boxplot(figsize = (5,5), rot = 90, fontsize= '8', grid = False)
# Out:
# <AxesSubplot:>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9056\543041900.py in <module>
#       1 x=df["trestbps"]
# ----> 2 x=np.sort(df["trestbps"])
#       3 plt.xlabel("Trestbps")
#       4 plt.plot(x)
#
# NameError: name 'np' is not defined

# %%
x=df["trestbps"]
x=np.sort(df["trestbps"])
plt.xlabel("Trestbps")
plt.plot(x)
