# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11256\4080736814.py in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11256\4080736814.py in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/47/17/5c4b04caa8fe1dca2aa940dcc00319aa77c84fbdb71f83869a0900cac660/pandas-1.1.5-cp37-cp37m-win_amd64.whl (8.7MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\rohit ranjan\appdata\local\programs\python\python37\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in c:\users\rohit ranjan\appdata\local\programs\python\python37\lib\site-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\rohit ranjan\appdata\local\programs\python\python37\lib\site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in c:\users\rohit ranjan\appdata\local\programs\python\python37\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.1.5
# Note: you may need to restart the kernel to use updated packages.
#   Cache entry deserialization failed, entry ignored
# mysql-connector-python 8.0.31 requires protobuf<=3.20.1,>=3.11.0, which is not installed.
# Cache entry deserialization failed, entry ignored
# You are using pip version 10.0.1, however version 23.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/df/3f/6093a23565d0f50ce433f56223fcc34af6c912cd4331dc582ba29d9b5a17/matplotlib-3.5.3-cp37-cp37m-win_amd64.whl (7.2MB)
# Requirement already satisfied: numpy>=1.17 in c:\users\rohit ranjan\appdata\local\programs\python\python37\lib\site-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\rohit ranjan\appdata\local\programs\python\python37\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\rohit ranjan\appdata\local\programs\python\python37\lib\site-packages (from matplotlib) (21.3)
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Using cached https://files.pythonhosted.org/packages/03/93/11790e8e81b89acd3a1c8a6b501f8a05b1c41beee0990582699cdda29557/kiwisolver-1.4.4-cp37-cp37m-win_amd64.whl
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached https://files.pythonhosted.org/packages/5c/f9/695d6bedebd747e5eb0fe8fad57b72fdf25411273a39791cde838d5a8f51/cycler-0.11.0-py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rohit ranjan\appdata\local\programs\python\python37\lib\site-packages (from matplotlib) (2.8.2)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached https://files.pythonhosted.org/packages/e3/d9/e9bae85e84737e76ebbcbea13607236da0c0699baed0ae4f1151b728a608/fonttools-4.38.0-py3-none-any.whl
# Collecting pillow>=6.2.0 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/18/c5/fbbcab5cc53c4278c1843d985c6e8e80c79f993c6c1e07f587f34afc76ee/Pillow-9.4.0-cp37-cp37m-win_amd64.whl (2.5MB)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in c:\users\rohit ranjan\appdata\local\programs\python\python37\lib\site-packages (from kiwisolver>=1.0.1->matplotlib) (4.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\rohit ranjan\appdata\local\programs\python\python37\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: kiwisolver, cycler, fonttools, pillow, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.4 matplotlib-3.5.3 pillow-9.4.0
# Note: you may need to restart the kernel to use updated packages.
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
# mysql-connector-python 8.0.31 requires protobuf<=3.20.1,>=3.11.0, which is not installed.
#   The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\users\rohit ranjan\appdata\local\programs\python\python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# You are using pip version 10.0.1, however version 23.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df = pd.read_csv('heart_disease_uci.csv')

# %%
df.head(1)
# Out:
#    id  age   sex    dataset              cp  trestbps   chol   fbs  \
# 0   1   63  Male  Cleveland  typical angina     145.0  233.0  True
#
#           restecg  thalch  exang  oldpeak        slope   ca          thal  num
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0  fixed defect    0

# %%
import matplotlib.pyplot as plt

# %%
df['trestbps'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['trestbps'].plot(kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17336\412406727.py in <module>
# ----> 1 df['trestbps'].plot(kind='scatter')
#
# c:\users\rohit ranjan\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     894                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     895             else:
# --> 896                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#     897         elif kind in self._series_kinds:
#     898             if isinstance(data, ABCDataFrame):
#
# ValueError: plot kind scatter can only be used for data frames

# %%
df['trestbps'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['trestbps'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['trestbps'].plot.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17336\37545063.py in <module>
# ----> 1 df['trestbps'].plot.scatter()
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %%
x=data["age"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3848\2611046389.py in <module>
# ----> 1 x=data["age"]
#
# NameError: name 'data' is not defined

# %%
x=df["age"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3848\1315635953.py in <module>
# ----> 1 x=df["age"]
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv('heart_disease_uci.csv')

# %%
import matplotlib.pyplot as plt

# %%
df['trestbps'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
x=df["age"]

# %%
y=df["trestbps"]

# %%
plt.scatter(x,y)

# %%
plt.xlabel("Age")
plt.ylabel("Trestbps")
plt.title("Heart Rate Disease Plot")
plt.show()

# %%
plt.xlabel("Age")
plt.ylabel("Trestbps")
plt.title("Heart Rate Disease Plot")
plt.scatter(x,y)
plt.show()

# %%
df.boxplot(figsize = (5,5), rot = 90, fontsize= '8', grid = False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,7))
plt.plot(x, y, marker=".", linestyle="none")
plt.xlabel("Age")
plt.ylabel("Trestbps")
# Out:
# Text(0, 0.5, 'Trestbps')

# %%
plt.plot(x, y)
plt.legend(('Normal Distribution', 'Empirical Data'), loc='lower right')

# %%
x=df["age"]
x=np.sort(df["age"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3848\731759767.py in <module>
#       1 x=df["age"]
# ----> 2 x=np.sort(df["age"])
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
x=df["age"]
x=np.sort(df["age"])

# %%
plt.plot(x)

# %%
x=df["trestbps"]
x=np.sort(df["trestbps"])
plt.xlabel("Trestbps")
plt.plot(x)
